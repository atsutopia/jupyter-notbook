# %%
# comment
print('hello')
# Out:
# hello

# %%
import pandas as pd

df = pd.read_csv('scount_2020_06_15-v2.csv', index_col=0, parse_dates=True)
df.head()
# Out:
#                      is_interested       name            type expired_on  \
# created_at
# 2016-07-31 11:05:00            0.0  TRUNK株式会社  PlatinumTicket   31/07/16
# 2016-04-08 11:40:00            1.0  TRUNK株式会社  PlatinumTicket   04/08/16
# 2016-04-08 12:18:00            0.0  TRUNK株式会社  PlatinumTicket   04/08/16
# 2016-08-19 09:42:00            1.0  TRUNK株式会社  PlatinumTicket   19/08/16
# 2017-02-03 08:14:00            0.0  TRUNK株式会社     VisitTicket   02/07/17
#
#                      start_on  \
# created_at
# 2016-07-31 11:05:00  31/07/16
# 2016-04-08 11:40:00  04/08/16
# 2016-04-08 12:18:00  04/08/16
# 2016-08-19 09:42:00  19/08/16
# 2017-02-03 08:14:00  02/03/17
#
#                                                            description  \
# created_at
# 2016-07-31 11:05:00  > 株式会社プリセプト　鈴木と申します。\r\n> \r\n> 貴殿のプロジェクト及びご経験...
# 2016-04-08 11:40:00  はじめまして、TRUNKの代表の西元と申します。\r\n原さんの「実績・活動」を拝見し、是非...
# 2016-04-08 12:18:00  はじめまして、TRUNKの代表の西元と申します。\r\n原さんの「スキル・実績」を拝見し、是...
# ...

# %%
from datetime import time

am = df.between_time(time(9, 0),time(12, 0))
print('am', len(am),  (am['is_interested'] == 1.0).sum())
# Out:
# am 562 80
